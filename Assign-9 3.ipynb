# %%
import re
text= "The rain in Spain falls mainly on the plain" 
result = re.findall("ai",text)
print(result)
# Out:
# ['ai', 'ai', 'ai', 'ai']

# %%
import re 
text = "Agent 47 is on the move"
result = re.sub("\d",'X',text)
print(result)
# Out:
# Agent XX is on the move

# %% [markdown]
# # Assignment - 9

# %%
# Q1.Write a program to save the cars dataset into a text file called cars.txt. 
# Each car's dictionary should be on a new line.

cars = [
    {
     "Company": "Ferrari", 
     'Car Name': 'Roma', 
     'Engine': 'V8',
     'HorsePower':612, 
     "Top Speed": "320km/h",
     "Price": 230000, 
     "Fuel": "Petrol", 
     "Seats": '2+2'
    },
    {
     "Company": "Lamborghini", 
     "Car Name": "Huracan", 
     "Engine": "V10",
     "HorsePower":640, 
     "Top Speed": "325km/h",
     "Price": 300000, 
     "Fuel": "Petrol", 
     "Seats": 2 
    },
    { 
     "Company": "Rolls Royce", 
     'Car Name': 'Ghost', 
     'Engine': 'V12',
     'HorsePower': 563, 
     "Top Speed": "250km/h",
     "Price": 315000, 
     "Fuel": "Petrol", 
     "Seats": 5 
    },
    { 
     "Company": "Mercedes", 
     'Car Name': 'AMG GT', 
     'Engine': 'V8',
     'HorsePower':523, 
     "Top Speed": "310km/h",
     "Price": 155000, 
     "Fuel": "Petrol", 
     "Seats": 2 
    },
    {  
     "Company": "BMW", 
     "Car Name": "M4", 
     "Engine": "I6",
     "HorsePower": 503, 
     "Top Speed": "290km/h",
     "Price": 75000, 
     "Fuel": "Petrol", 
     "Seats": 4 
    },
    { 
     "Company": "Toyota", 
     'Car Name': 'Supra', 
     'Engine': 'I4',
     'HorsePower':382, 
     "Top Speed": "250km/h",
     "Price": 54000, 
     "Fuel": "Petrol", 
     "Seats": 2 
    },
    { 
     "Company": "Audi", 
     'Car Name': 'R8', 
     'Engine': 'V10',
     'HorsePower':602, 
     "Top Speed": "320km/h",
     "Price": 170000, 
     "Fuel": "Petrol", 
     "Seats": 2 },
    { 
     "Company": "Aston Martin", 
     'Car Name': 'Vantage', 
     'Engine': 'V12',
     'HorsePower':563, 
     "Top Speed": "250km/h",
     "Price": 315000, 
     "Fuel": "Petrol", 
     "Seats": 5 }
]

import pandas as pd
df = pd.DataFrame(cars)
print(df)

with open("cars.txt",'w') as f:
    for d in cars:
        f.write(str(d)+'\n')
with open('cars.txt','r') as f:
    print(f.read())
# Out:
#         Company Car Name Engine  HorsePower Top Speed   Price    Fuel Seats
# 0       Ferrari     Roma     V8         612   320km/h  230000  Petrol   2+2
# 1   Lamborghini  Huracan    V10         640   325km/h  300000  Petrol     2
# 2   Rolls Royce    Ghost    V12         563   250km/h  315000  Petrol     5
# 3      Mercedes   AMG GT     V8         523   310km/h  155000  Petrol     2
# 4           BMW       M4     I6         503   290km/h   75000  Petrol     4
# 5        Toyota    Supra     I4         382   250km/h   54000  Petrol     2
# 6          Audi       R8    V10         602   320km/h  170000  Petrol     2
# 7  Aston Martin  Vantage    V12         563   250km/h  315000  Petrol     5
# {'Company': 'Ferrari', 'Car Name': 'Roma', 'Engine': 'V8', 'HorsePower': 612, 'Top Speed': '320km/h', 'Price': 230000, 'Fuel': 'Petrol', 'Seats': '2+2'}
# ...

# %%
# Q2. Assuming a cars.txt file exists from the previous question, 
# write a program to read its contents and display them in a clean format.
import re

with open('cars.txt','r') as f:
    for line in f:
        for i in line.split(","):
            print(i)

# with open('cars.txt','r') as f:
#     print(f.read())
# Out:
# {'Company': 'Ferrari'
#  'Car Name': 'Roma'
#  'Engine': 'V8'
#  'HorsePower': 612
#  'Top Speed': '320km/h'
#  'Price': 230000
#  'Fuel': 'Petrol'
#  'Seats': '2+2'}
#
# {'Company': 'Lamborghini'
#  'Car Name': 'Huracan'
#  'Engine': 'V10'
#  'HorsePower': 640
#  'Top Speed': '325km/h'
#  'Price': 300000
#  'Fuel': 'Petrol'
#  'Seats': 2}
#
# {'Company': 'Rolls Royce'
#  'Car Name': 'Ghost'
#  'Engine': 'V12'
#  'HorsePower': 563
#  'Top Speed': '250km/h'
#  'Price': 315000
#  'Fuel': 'Petrol'
#  'Seats': 5}
#
# {'Company': 'Mercedes'
#  'Car Name': 'AMG GT'
#  'Engine': 'V8'
#  'HorsePower': 523
#  'Top Speed': '310km/h'
#  'Price': 155000
#  'Fuel': 'Petrol'
#  'Seats': 2}
#
# {'Company': 'BMW'
#  'Car Name': 'M4'
#  'Engine': 'I6'
#  'HorsePower': 503
#  'Top Speed': '290km/h'
#  'Price': 75000
#  'Fuel': 'Petrol'
#  'Seats': 4}
#
# {'Company': 'Toyota'
#  'Car Name': 'Supra'
#  'Engine': 'I4'
#  'HorsePower': 382
#  'Top Speed': '250km/h'
#  'Price': 54000
#  'Fuel': 'Petrol'
# ...

# %%
# Q3. Write a program to first save the cars dataset into a CSV file named cars.csv.
# Then, read the CSv file and print only the Company and Price for each car.

import csv
# with open("cars.txt",'r')as t:
#     # print(t.read())
#     data = t.read()
cars = [
    {
     "Company": "Ferrari", 
     'Car Name': 'Roma', 
     'Engine': 'V8',
     'HorsePower':612, 
     "Top Speed": "320km/h",
     "Price": 230000, 
     "Fuel": "Petrol", 
     "Seats": '2+2'
    },
    {
     "Company": "Lamborghini", 
     "Car Name": "Huracan", 
     "Engine": "V10",
     "HorsePower":640, 
     "Top Speed": "325km/h",
     "Price": 300000, 
     "Fuel": "Petrol", 
     "Seats": 2 
    },
    { 
     "Company": "Rolls Royce", 
     'Car Name': 'Ghost', 
     'Engine': 'V12',
     'HorsePower': 563, 
     "Top Speed": "250km/h",
     "Price": 315000, 
     "Fuel": "Petrol", 
     "Seats": 5 
    },
    { 
     "Company": "Mercedes", 
     'Car Name': 'AMG GT', 
     'Engine': 'V8',
     'HorsePower':523, 
     "Top Speed": "310km/h",
     "Price": 155000, 
     "Fuel": "Petrol", 
     "Seats": 2 
    },
    {  
     "Company": "BMW", 
     "Car Name": "M4", 
     "Engine": "I6",
     "HorsePower": 503, 
     "Top Speed": "290km/h",
     "Price": 75000, 
     "Fuel": "Petrol", 
     "Seats": 4 
    },
    { 
     "Company": "Toyota", 
     'Car Name': 'Supra', 
     'Engine': 'I4',
     'HorsePower':382, 
     "Top Speed": "250km/h",
     "Price": 54000, 
     "Fuel": "Petrol", 
     "Seats": 2 
    },
    { 
     "Company": "Audi", 
     'Car Name': 'R8', 
     'Engine': 'V10',
     'HorsePower':602, 
     "Top Speed": "320km/h",
     "Price": 170000, 
     "Fuel": "Petrol", 
     "Seats": 2 },
    { 
     "Company": "Aston Martin", 
     'Car Name': 'Vantage', 
     'Engine': 'V12',
     'HorsePower':563, 
     "Top Speed": "250km/h",
     "Price": 315000, 
     "Fuel": "Petrol", 
     "Seats": 5 }
]

fieldnames= ['Company','Car Name','Engine','HorsePower','Top Speed','Price','Fuel', 'Seats']

with open('cars.csv','w') as f:
    writer = csv.DictWriter(f,fieldnames=fieldnames)
    writer.writerows(cars)

with open("cars.csv",'r')as z:
    reader = csv.reader(z)
    for rows in  reader:
        if rows != []:
            print(f"Carname: {rows[0]}, Price: {rows[-3]}")
# Out:
# Carname: Ferrari, Price: 230000
# Carname: Lamborghini, Price: 300000
# Carname: Rolls Royce, Price: 315000
# Carname: Mercedes, Price: 155000
# Carname: BMW, Price: 75000
# Carname: Toyota, Price: 54000
# Carname: Audi, Price: 170000
# Carname: Aston Martin, Price: 315000

# %%
# Q4. Write a program to first convert the cars dataset into JSON format and save it as cars.json. 
# Then, read the JSON file and display all car names with their corresponding horsepower.
cars = [
    {
     "Company": "Ferrari", 
     'Car Name': 'Roma', 
     'Engine': 'V8',
     'HorsePower':612, 
     "Top Speed": "320km/h",
     "Price": 230000, 
     "Fuel": "Petrol", 
     "Seats": '2+2'
    },
    {
     "Company": "Lamborghini", 
     "Car Name": "Huracan", 
     "Engine": "V10",
     "HorsePower":640, 
     "Top Speed": "325km/h",
     "Price": 300000, 
     "Fuel": "Petrol", 
     "Seats": 2 
    },
    { 
     "Company": "Rolls Royce", 
     'Car Name': 'Ghost', 
     'Engine': 'V12',
     'HorsePower': 563, 
     "Top Speed": "250km/h",
     "Price": 315000, 
     "Fuel": "Petrol", 
     "Seats": 5 
    },
    { 
     "Company": "Mercedes", 
     'Car Name': 'AMG GT', 
     'Engine': 'V8',
     'HorsePower':523, 
     "Top Speed": "310km/h",
     "Price": 155000, 
     "Fuel": "Petrol", 
     "Seats": 2 
    },
    {  
     "Company": "BMW", 
     "Car Name": "M4", 
     "Engine": "I6",
     "HorsePower": 503, 
     "Top Speed": "290km/h",
     "Price": 75000, 
     "Fuel": "Petrol", 
     "Seats": 4 
    },
    { 
     "Company": "Toyota", 
     'Car Name': 'Supra', 
     'Engine': 'I4',
     'HorsePower':382, 
     "Top Speed": "250km/h",
     "Price": 54000, 
     "Fuel": "Petrol", 
     "Seats": 2 
    },
    { 
     "Company": "Audi", 
     'Car Name': 'R8', 
     'Engine': 'V10',
     'HorsePower':602, 
     "Top Speed": "320km/h",
     "Price": 170000, 
     "Fuel": "Petrol", 
     "Seats": 2 
    },
    { 
     "Company": "Aston Martin", 
     'Car Name': 'Vantage', 
     'Engine': 'V12',
     'HorsePower':563, 
     "Top Speed": "250km/h",
     "Price": 315000, 
     "Fuel": "Petrol", 
     "Seats": 5 
    }
]
import json

with open("cars.json",'w') as f:
    # for rows in cars:
    json.dump(cars,f,indent=4)

with open("cars.json","r") as file:
    cars = json.load(file)
    for i in cars: 
        for k,v in i.items():
            if k =='Car Name' or k =="HorsePower" :
                print(k,":",v,"\n",end="")
        print()
# Out:
# Car Name : Roma
# HorsePower : 612
#
# Car Name : Huracan
# HorsePower : 640
#
# Car Name : Ghost
# HorsePower : 563
#
# Car Name : AMG GT
# HorsePower : 523
#
# Car Name : M4
# HorsePower : 503
#
# Car Name : Supra
# HorsePower : 382
#
# Car Name : R8
# HorsePower : 602
#
# Car Name : Vantage
# HorsePower : 563

# %%
# display all car names with their corresponding horsepower.

with open("cars.json","r") as file:
    cars = json.load(file)
    for car in cars: 
        print(f"{car['Car Name']}: {car['HorsePower']}")
# Out:
# Roma: 612
# Huracan: 640
# Ghost: 563
# AMG GT: 523
# M4: 503
# Supra: 382
# R8: 602
# Vantage: 563

# %%
# Q5. Write a program that attempts to open a non-existent file (e.g., unknown.csv).
# Use a try...except block to catch the fileNotfoundError and 
# print "file not found". in a finally block, always print "execution completed".

import csv
try :
    with open("unknown.csv","r") as f:
         f.read()
except FileNotFoundError: 
    print("File not found")
finally: 
    print("execution completed")
# Out:
# File not found
# execution completed

# %%
##### Q6. Write a program that asks the user to enter a row number. 
# Using a try...except block, attempt to print the car dictionary from the cars list at that index. 
# If the number is out of range, handle the IndexError by printing "Invalid row number".

cars = [
    {
     "Company": "Ferrari", 
     'Car Name': 'Roma', 
     'Engine': 'V8',
     'HorsePower':612, 
     "Top Speed": "320km/h",
     "Price": 230000, 
     "Fuel": "Petrol", 
     "Seats": '2+2'
    },
    {
     "Company": "Lamborghini", 
     "Car Name": "Huracan", 
     "Engine": "V10",
     "HorsePower":640, 
     "Top Speed": "325km/h",
     "Price": 300000, 
     "Fuel": "Petrol", 
     "Seats": 2 
    },
    { 
     "Company": "Rolls Royce", 
     'Car Name': 'Ghost', 
     'Engine': 'V12',
     'HorsePower': 563, 
     "Top Speed": "250km/h",
     "Price": 315000, 
     "Fuel": "Petrol", 
     "Seats": 5 
    },
    { 
     "Company": "Mercedes", 
     'Car Name': 'AMG GT', 
     'Engine': 'V8',
     'HorsePower':523, 
     "Top Speed": "310km/h",
     "Price": 155000, 
     "Fuel": "Petrol", 
     "Seats": 2 
    },
    {  
     "Company": "BMW", 
     "Car Name": "M4", 
     "Engine": "I6",
     "HorsePower": 503, 
     "Top Speed": "290km/h",
     "Price": 75000, 
     "Fuel": "Petrol", 
     "Seats": 4 
    },
    { 
     "Company": "Toyota", 
     'Car Name': 'Supra', 
     'Engine': 'I4',
     'HorsePower':382, 
     "Top Speed": "250km/h",
     "Price": 54000, 
     "Fuel": "Petrol", 
     "Seats": 2 
    },
    { 
     "Company": "Audi", 
     'Car Name': 'R8', 
     'Engine': 'V10',
     'HorsePower':602, 
     "Top Speed": "320km/h",
     "Price": 170000, 
     "Fuel": "Petrol", 
     "Seats": 2 
    },
    { 
     "Company": "Aston Martin", 
     'Car Name': 'Vantage', 
     'Engine': 'V12',
     'HorsePower':563, 
     "Top Speed": "250km/h",
     "Price": 315000, 
     "Fuel": "Petrol", 
     "Seats": 5 
    }
]
try :
    row_no = int(input("Enter row number:"))    
    print(cars[row_no])
except IndexError :
    print("Invalid row number")
# Out:
# Enter row number: 10
# Invalid row number

# %%
# Q7. Write a function get_car_price(car_name) that takes a car name as input. 
# It should search the cars dataset and return the price. If the car does not exist, 
# it must raise a ValueError with the message "Car not found".
cars = [
    {
     "Company": "Ferrari", 
     'Car Name': 'Roma', 
     'Engine': 'V8',
     'HorsePower':612, 
     "Top Speed": "320km/h",
     "Price": 230000, 
     "Fuel": "Petrol", 
     "Seats": '2+2'
    },
    {
     "Company": "Lamborghini", 
     "Car Name": "Huracan", 
     "Engine": "V10",
     "HorsePower":640, 
     "Top Speed": "325km/h",
     "Price": 300000, 
     "Fuel": "Petrol", 
     "Seats": 2 
    },
    { 
     "Company": "Rolls Royce", 
     'Car Name': 'Ghost', 
     'Engine': 'V12',
     'HorsePower': 563, 
     "Top Speed": "250km/h",
     "Price": 315000, 
     "Fuel": "Petrol", 
     "Seats": 5 
    },
    { 
     "Company": "Mercedes", 
     'Car Name': 'AMG GT', 
     'Engine': 'V8',
     'HorsePower':523, 
     "Top Speed": "310km/h",
     "Price": 155000, 
     "Fuel": "Petrol", 
     "Seats": 2 
    },
    {  
     "Company": "BMW", 
     "Car Name": "M4", 
     "Engine": "I6",
     "HorsePower": 503, 
     "Top Speed": "290km/h",
     "Price": 75000, 
     "Fuel": "Petrol", 
     "Seats": 4 
    },
    { 
     "Company": "Toyota", 
     'Car Name': 'Supra', 
     'Engine': 'I4',
     'HorsePower':382, 
     "Top Speed": "250km/h",
     "Price": 54000, 
     "Fuel": "Petrol", 
     "Seats": 2 
    },
    { 
     "Company": "Audi", 
     'Car Name': 'R8', 
     'Engine': 'V10',
     'HorsePower':602, 
     "Top Speed": "320km/h",
     "Price": 170000, 
     "Fuel": "Petrol", 
     "Seats": 2 
    },
    { 
     "Company": "Aston Martin", 
     'Car Name': 'Vantage', 
     'Engine': 'V12',
     'HorsePower':563, 
     "Top Speed": "250km/h",
     "Price": 315000, 
     "Fuel": "Petrol", 
     "Seats": 5 
    }
]


def get_car_price(car_name):
    for i in cars:
        for k,v in i.items():
            if v == car_name:
                if i[k] == v:
                    print("Price:",i['Price'])
            else: 
                raise ValueError("Car not found")
                
car_name = input("Enter the car name:") 
get_car_price(car_name)

def get_car_price(car_name):
    for car in cars:
        if car.get("Name") == car_name:
            return car["Price"]
    
    # If loop ends without returning
    raise ValueError("Car not found")


car_name = input("Enter the car name: ")
try:
    print("Price:", get_car_price(car_name))
except ValueError as e:
    print(e)
# Out:
# Enter the car name: Buggati
# Car not found
# Enter the car name:  BMW
# Car not found

# %%
# Q8. Write a function check_hp(hp) that takes a horsepower value as input. 
# If the horsepower is less than 100, the function should raise a generic Exception 
# with the message "Invalid horsepower". Otherwise, it should print "Valid horsepower: [hp]".

cars = [
    {
     "Company": "Ferrari", 
     'Car Name': 'Roma', 
     'Engine': 'V8',
     'HorsePower':612, 
     "Top Speed": "320km/h",
     "Price": 230000, 
     "Fuel": "Petrol", 
     "Seats": '2+2'
    },
    {
     "Company": "Lamborghini", 
     "Car Name": "Huracan", 
     "Engine": "V10",
     "HorsePower":640, 
     "Top Speed": "325km/h",
     "Price": 300000, 
     "Fuel": "Petrol", 
     "Seats": 2 
    },
    { 
     "Company": "Rolls Royce", 
     'Car Name': 'Ghost', 
     'Engine': 'V12',
     'HorsePower': 563, 
     "Top Speed": "250km/h",
     "Price": 315000, 
     "Fuel": "Petrol", 
     "Seats": 5 
    },
    { 
     "Company": "Mercedes", 
     'Car Name': 'AMG GT', 
     'Engine': 'V8',
     'HorsePower':523, 
     "Top Speed": "310km/h",
     "Price": 155000, 
     "Fuel": "Petrol", 
     "Seats": 2 
    },
    {  
     "Company": "BMW", 
     "Car Name": "M4", 
     "Engine": "I6",
     "HorsePower": 503, 
     "Top Speed": "290km/h",
     "Price": 75000, 
     "Fuel": "Petrol", 
     "Seats": 4 
    },
    { 
     "Company": "Toyota", 
     'Car Name': 'Supra', 
     'Engine': 'I4',
     'HorsePower':382, 
     "Top Speed": "250km/h",
     "Price": 54000, 
     "Fuel": "Petrol", 
     "Seats": 2 
    },
    { 
     "Company": "Audi", 
     'Car Name': 'R8', 
     'Engine': 'V10',
     'HorsePower':602, 
     "Top Speed": "320km/h",
     "Price": 170000, 
     "Fuel": "Petrol", 
     "Seats": 2 
    },
    { 
     "Company": "Aston Martin", 
     'Car Name': 'Vantage', 
     'Engine': 'V12',
     'HorsePower':563, 
     "Top Speed": "250km/h",
     "Price": 315000, 
     "Fuel": "Petrol", 
     "Seats": 5 
    }
]

def check_hp(hp):
   if hp < 100:
       raise Exception("Invalid horsepower")
   else :
       print(f"Valid horsepower, {hp}")
            

hp = int(input("Enter the horsepower: "))
# try :
check_hp(hp)
# except Exception as e:  
       # print(e)
# Out:
# Enter the horsepower:  10000
# Valid horsepower, 10000
