# %% [markdown]
# # Assignment 8

# %%
# Q1 
def create_greeting (name ,message= 'Hello'): 
    return (f"{message},{name}!")

print(create_greeting('Tushar'))
# Out:
# Hello,Tushar!

# %%
# Q2
def sum_all(*n):
    return sum(n)
    
print("Sum all numbers",sum_all(1,2,3,4,5))
# Out:
# Sum all numbers 15

# %%
# Q3
def create_build_profile(**d):
   return d
print(create_build_profile(Name='Tushar',Age= 23, Location= 'Ambala'))
# Out:
# {'Name': 'Tushar', 'Age': 23, 'Location': 'Ambala'}

# %%
def describe_pet(animal_type,pet_name,owner_name='Maria'): 
    print(f'I have a {animal_type} name {pet_name}.') 
    print(f"its onwer is {owner_name}.\n")
    
describe_pet("hamster","Harry") 

describe_pet(pet_name ='Whiskers',animal_type="cat") 

describe_pet("dog","Rex","Paul")
# Out:
# I have a hamster name Harry.
# its onwer is Maria.
#
# I have a cat name Whiskers.
# its onwer is Maria.
#
# I have a dog name Rex.
# its onwer is Paul.

# %%
x = 100 
def update_value():
    x =25 
    print(f"Inside function: {x}") 
    
update_value() 
print(f"outside function: {x}")
# Out:
# Inside function: 25
# outside function: 100

# %%
counter = 0
def increment_counter():
    global counter 
    counter = counter + 1
    return (counter)

increment_counter()
increment_counter()
print(increment_counter())
# Out:
# 3

# %%
import math
def circle_stats(r):
    circumferrence = 2 * math.pi * r
    area = math.pi * r * r
    print("Circumferrence of a circle: ",circumferrence)
    print("Area of a cicle: ",area)

circle_stats(5)
# Out:
# Circumferrence of a circle:  31.41592653589793
# Area of a cicle:  78.53981633974483

# %%
# Q7
import math
def circle_stats(r):
    print("Circumferrence: ",2 * math.pi * r)
    print("Area of circle: ",math.pi * r *r)

# circle_stats()
import math
def circle_stats(r):
    return ((f"Circumferrence: { 2 * math.pi * r}"),(f"Area: {math.pi * r * r} "), )
    
print(circle_stats(5))
# Out:
# ('Circumferrence: 31.41592653589793', 'Area: 78.53981633974483 ')

# %%
# Q8
import random
def guess_the_number(start,stop):
    print("Random no: ",random.randint(start,stop))

guess_the_number(1,20)

import random
def guess_the_number():

    user_input = int(input("Guess one no between 1 and 20: "))
    random_no=  random.randint(1,21)

    if (user_input == random_no)  :
       print("You got it!")
    else: 
       print(f"Sorry, the number was {random_no}")

guess_the_number()
# Out:
# Random no:  11
# Guess one no between 1 and 20:  5
# Sorry, the number was 3

# %%
import random
l = [1,2,3,4,5]
random.shuffle(l)
print(l)

import random
def shuffle_list (l):
  random.shuffle(l)
  print(l)

# l = input("Enter elements for the list separated by ,: ")
# l = list(l.split(","))

# print(l,type(l))
l = [1,2,3,4]
shuffle_list(l)
# Out:
# [2, 4, 1, 3, 5]
# [2, 3, 1, 4]

# %%
# change format of time into another format to increase readability 
import datetime
now = datetime.datetime.now()
#string format time
# %Y : Year with century (2025)
# %m : Month name
formatted = now.strftime("%B %Y %A,%d %I:%M %p")
print(formatted)
# Out:
# November 2025 Wednesday,19 08:01 PM

# %%
import datetime
# now = datetime.datetime.now()
# formatted = datetime.datetime.now().strftime(" %B %d, %Y")
print(datetime.datetime.today().strftime("%B %d, %Y"))
import datetime
now = datetime.datetime.today()
print(now.strftime('%B %d, %Y'))
# Out:
# November 20, 2025
# November 20, 2025

# %%
import datetime 
now = datetime.datetime.today() 
formatted = now.strftime("%d-%m-%Y")
date1 = datetime.datetime.strptime(formatted, "%d-%m-%Y")
date2 = datetime.datetime.strptime("01-01-2026", "%d-%m-%Y")

difference = date2 - date1
print(difference.days)
# Out:
# 43

# %%
import datetime
now = datetime.datetime.today()
formatted = now.strftime("%m-%d-%Y")
date1 = datetime.datetime.strptime(formatted,"%m-%d-%Y") 
date2 = datetime.datetime.strptime("01-01-2026","%m-%d-%Y")
print("Difference of days: ",(date2 - date1).days)
# Out:
# Difference of days:  43

# %%
import datetime
now = datetime.datetime.today()
next_yr = datetime.datetime(now.year+1,1,1)
print((next_yr-now).days)
# Out:
# 42

# %%
import datetime

def days_until_new_year():
    now = datetime.datetime.today()
    next_yr = datetime.datetime(now.year+1,1,1)
    return ((next_yr-now).days)
    
days_until_new_year()
# Out:
# 41

# %%
import random
def lottery_numbers():
    # sample takes two arguements,
    # 1st: iterable, range of no's, 
    # 2nd: no of desired outcomes from that iterable, range of no's   
    return (random.sample(range(1,50),6))

print(lottery_numbers())
# Out:
# [3, 46, 37, 32, 29, 11]
